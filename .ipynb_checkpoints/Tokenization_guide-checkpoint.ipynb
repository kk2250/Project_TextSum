# %%
import spacy
nlp = spacy.load('en')

# %%
docx = nlp("Spacy is an amazing tool and you know it")

# %%
docx
# Out:
# Spacy is an amazing tool and you know it

# %%
docx2 = nlp(u"Spacy is an amazing toolkit")

# %%
docx2
# Out:
# Spacy is an amazing toolkit

# %%
myfile = open("data/DUC2001/AP830325-0143").read()

# %%
doc_file = nlp(myfile)

# %%
doc_file
# Out:
# <DOC>
# <DOCNO> AP890325-0143 </DOCNO>
# <FILEID>AP-NR-03-25-89 2357EST</FILEID>
# <FIRST>u a AM-TankerSpill 3rdLd-Writethru a0598 03-25 1274</FIRST>
# <SECOND>AM-Tanker Spill, 3rd Ld-Writethru, a0598,1306</SECOND>
# <HEAD>Workers Try To Unload Tanker; Environmentalists Call Spill a Disaster</HEAD>
# <HEAD>Eds: INSERTS 2 grafs after 32nd, `He said...' to UPDATE with Coast
# Guard issuing subpoena to ship's master and two crewmen; picks up 33rd
# graf pvs, `Previously, the...'</HEAD>
# <HEAD>LaserPhotos AG1,2,3,4</HEAD>
# <BYLINE>By SUSAN GALLAGHER</BYLINE>
# <BYLINE>Associated Press Writer</BYLINE>
# <DATELINE>VALDEZ, Alaska (AP) </DATELINE>
# <TEXT>
#    Millions of gallons of crude oil that
# spilled when a tanker ran aground spread across a wildlife-rich
# stretch of ocean Saturday, and Alaska's chief environmental officer
# criticized cleanup efforts as too slow.
#    The biggest oil spill in U.S. history created a slick about
# seven miles long and seven miles wide in Prince William Sound. The
# Coast Guard said only Reef Island and the western edge of Bligh
# Island had been touched by the slick.
#    ``This situation, I think, was everyone's secret nightmare about
# what could happen with oil traffic in the sound,'' said Dennis
# Kelso, commissioner of the Alaska Department of Environmental
# Conservation.
#    Some 240,000 barrels _ about 10,080,000 gallons _ of crude oil
# from Alaska's North Slope spilled early Friday when the 987-foot
# tanker Exxon Valdez ran hard aground on Bligh Reef, about 25 miles
# outside Valdez, where it had taken on a total cargo of 1.2 million
# barrels. Initial reports indicated 270,000 barrels had spilled.
#    ``What we have here is a major environmental catastrophe,'' said
# one oil spill expert, Richard Golob of Boston, publisher of Golob
# Oil Pollution Bulletin.
#    Golob said cleanup equipment at the site was ``grossly
# inadequate'' but added that even under ideal circumstances cleanup
# efforts would not have significantly reduced the spill's impact.
#    ``It is an enclosed body of water,'' he said. ``The only way for
# this oil to ecape out to the sea is by traversing the entire length
# of Prince William Sound with all its islands, fjords and bays and
# channels.
#    ``And during that transit, undoubtedly a large stretch of
# shoreline will be contaminated,'' he said.
#    Divers Saturday said they had found six to eight holes in the
# vessel's hull large enough to swim through, said Frank Iarossi,
# president of Exxon Shipping Co. About 30 feet of the vessel is
# resting on a shelf on the reef.
#    Efforts to begin pumping 200,000 gallons of oil off the Exxon
# Valdez onto another tanker, the Exxon Baton Rouge, were halted
# early Saturday when authorities noticed that oil appeared to
# leaking as the pumping operation proceeded.
#    Eleven of 17 tanks that lie forward of the ship's masthead were
# ruptured in the accident, causing concern over removal of the oil,
# said Coast Guard Lt. Ed Wieliczkiewicz.
# the grounding, but he said he didn't know know how many people were
# tested or the results. McCall said the tests routinely are
# administered in marine accidents involving federal jurisdiction.
#    The Coast Guard issued a statement late Saturday that McCall has
# subpoenaed the ship's master and two crew members.
#    The subpoenas require them to make themselves available to NTSB
# investigators arriving Sunday. The Coast Guard said the supoenas
# were routine.
#    Previously, the largest U.S. tanker spill was the Dec. 15, 1976,
# grounding of the Argo Merchant tanker off the Nantucket shoals off
# Massachusetts, in which 7.6 million gallons of oil spilled, Golob
# said.
#    Up to 10.7 million gallons of oil was lost on Nov. 1, 1979, when
# the tanker Burmah Agate collided with another ship in Galveston
# Bay, Texas. However, that oil burned as well as spilled.
#    The largest tanker spill in history resulted from the July 19,
# 1979, collision off Tobago of the supertankers Atlantic Empress and
# Aegean Captain, in which 300,000 tons _ more than 80 million
# gallons _ of oil was lost.
# </TEXT>
# </DOC>

# %%
for sentence in doc_file.sents:
    print(sentence)
# Out:
# <DOC>
# <DOCNO> AP890325-0143 </DOCNO>
# <FILEID>AP-NR-03-25-89 2357EST</FILEID>
#
# <FIRST>u a AM-TankerSpill 3rdLd-Writethru a0598
# 03-25 1274</FIRST>
#
# <SECOND>AM-Tanker Spill, 3rd Ld-Writethru, a0598,1306</SECOND>
#
# <HEAD>
# Workers Try To Unload Tanker; Environmentalists Call Spill a Disaster</HEAD>
# <HEAD>Eds: INSERTS 2 grafs after 32nd, `He said...' to UPDATE with Coast
# Guard issuing subpoena to ship's master and two crewmen; picks up 33rd
# graf pvs, `Previously, the...'</HEAD>
# <HEAD>LaserPhotos AG1,2,3,4</HEAD>
#
# <BYLINE>
# By SUSAN GALLAGHER</BYLINE>
#
# <BYLINE>Associated Press Writer</BYLINE>
#
# <DATELINE>
# VALDEZ, Alaska (AP) </DATELINE
# >
#
# <TEXT>
#
# Millions of gallons of crude oil that
# spilled when a tanker ran aground spread across a wildlife-rich
# stretch of ocean Saturday, and Alaska's chief environmental officer
# criticized cleanup efforts as too slow.
#
# The biggest oil spill in U.S. history created a slick about
# seven miles long and seven miles wide in Prince William Sound.
# The
# Coast Guard said only Reef Island and the western edge of Bligh
# Island had been touched by the slick.
#
# ``This situation, I think, was everyone's secret nightmare about
# what could happen with oil traffic in the sound,'' said Dennis
# Kelso, commissioner of the Alaska Department of Environmental
# Conservation.
#
# Some 240,000 barrels _ about 10,080,000 gallons _ of crude oil
# from Alaska's North Slope spilled early Friday when the 987-foot
# tanker Exxon Valdez ran hard aground on Bligh Reef, about 25 miles
# outside Valdez, where it had taken on a total cargo of 1.2 million
# barrels.
# Initial reports indicated 270,000 barrels had spilled.
#
# ``What we have here is a major environmental catastrophe,'' said
# one oil spill expert, Richard Golob of Boston, publisher of Golob
# Oil Pollution Bulletin.
#
# Golob said cleanup equipment at the site was ``grossly
# inadequate'' but added that even under ideal circumstances cleanup
# efforts would not have significantly reduced the spill's impact.
#
# ``It is an enclosed body of water,'' he said.
# ``The only way for
# this oil to ecape out to the sea is by traversing the entire length
# of Prince William Sound with all its islands, fjords and bays and
# channels.
#
# ``And during that transit, undoubtedly a large stretch of
# shoreline will be contaminated,'' he said.
#
# Divers Saturday said they had found six to eight holes in the
# vessel's hull large enough to swim through, said Frank Iarossi,
# president of Exxon Shipping Co.
# About 30 feet of the vessel is
# resting on a shelf on the reef.
#
# Efforts to begin pumping 200,000 gallons of oil off the Exxon
# Valdez onto another tanker, the Exxon Baton Rouge, were halted
# early Saturday when authorities noticed that oil appeared to
# leaking as the pumping operation proceeded.
#
# Eleven of 17 tanks that lie forward of the ship's masthead were
# ruptured in the accident, causing concern over removal of the oil,
# said Coast Guard Lt.
# Ed Wieliczkiewicz.
#
# ``Whenever you start removing oil from a vessel this size it has
# to be done in a controlled manner,'' Wieliczkiewicz said.
# ``If it's
# not ... you endanger the stability of the vessel.''
#
# Wieliczkiewicz said a boom was placed around the Exxon Valdez
# and the Exxon Baton Rouge to help contain oil around the vessels.
#
# He also said four members of the Coast Guard's Pacific Strike
# Team from San Francisco, specially trained to deal with pollution
# and oil spills, arrived Saturday and were helping to rig pumps and
# assemble equipment needed to transfer oil to the Baton Rouge.
#
# Kelso was highly critical of what he said was a slow response to
# the spill.
#
# ``The initial reponse was inadequate and unacceptable,'' he said
# before a news conference Saturday.
# Kelso said the efforts should
# have been under way in five hours, but took much longer.
# ``You miss
# the opportunity right at the beginning
# and you've missed our best
# opportunity to do something.''
#
# Kelso said Alaska has a plan for oil spills that calls for
# action within five hours of a spill.
# It took several hours longer,
# he said, and only two of seven skimmers available to the Alyeska
# Pipeline Service Co. were used at the outset.
#
# Alyeska spokesman Chuck O'Donnel said he was satisfied with his
# company's actions.
# ``I think our people did an excellent job,'' he
# said.
#
# The spill's effect on wildlife had not yet been assessed, but
# commercial fishermen who depend on the sound for a catch worth
# millions of dollars were outraged and said a key herring spawning
# area had been polluted.
#
# ``The whole food chain could be affected by the spill,'' said
# Alan Reichman, ocean ecology coordinator for the environmental
# group Greenpeace, in Seattle.
#
# ``There's a high concentration of sea otter, waterfowl, sea
# birds and pink salmon in that area,'' said Steve Goldstein, a
# spokesman for the Interior Department in Washington.
# ``Some birds
# have already died, and we are doing our best to try to save the
# fish by containing the oil to the area where it presently is and by
# trying to skim it.''
#
# Whales, porpoises and seals are also common in Prince William
# Sound.
# ``It's kind of like sailing through a zoo,'' said Jim
# Lethcoe, who lives on a boat in the sound and operates a sailing
# business.
#
# An animal cleanup station was set up in a building at the
# community college in Valdez, but volunteers there said they had no
# animals to work on by midafternoon.
#
# The response to the spill also drew fire from the 12,000-member
# United Fishermen of Alaska.
#
# ``We feel that this should have been the easiest oil spill in
# the world to clean up,'' said Riki Ott, chairman of the
# organization's habitat committee.
# She noted that the spill had
# occurred in a protected area close to the Valdez marine terminal
# and the water was calm.
#
# Ott said the spill had polluted Prince William Sound's primary
# herring spawning area.
# Fishermen also take salmon and shellfish
# from the sound.
# Last year, they were paid about $85 million for
# their catches, she said.
#
# The Port of Valdez remained closed to tanker traffic.
# North
# Slope crude oil is shipped 800 miles through the trans-Alaska oil
# pipeline from Prudhoe Bay south to Valdez for shipment aboard
# tankers to refineries outside Alaska.
#
# The Coast Guard said the Exxon Valdez struck the reef when it
# maneuvered outside normal tanker traffic lanes to avoid icebergs.
#
# The vessel's captain, Joseph Hazelwood, has worked for Exxon for
# 20 years, at least 10 as a ship's master.
# It was unclear if a pilot
# was aboard the Exxon Valdez when it grounded.
#
# There was no decision Saturday on whether to use chemicals to
# disperse the oil, but a test of the dispersal method was being
# conducted Saturday afternoon, as was a test to determine whether at
# least some of the crude oil could be burned.
#
# Coast Guard Cmdr.
# Steven McCall said National Transportation
# Safety Board investigators are expected to arrive Sunday to take
# over the accident probe.
#
# He said one or more blood-alcohol tests were administered after
# the grounding, but he said he didn't know know how many people were
# tested or the results.
# McCall said the tests routinely are
# administered in marine accidents involving federal jurisdiction.
#
# The Coast Guard issued a statement late Saturday that McCall has
# subpoenaed the ship's master and two crew members.
#
# The subpoenas require them to make themselves available to NTSB
# investigators arriving Sunday.
# The Coast Guard said the supoenas
# were routine.
#
# Previously, the largest U.S. tanker spill was the Dec. 15, 1976,
# grounding of the Argo Merchant tanker off the Nantucket shoals off
# Massachusetts, in which 7.6 million gallons of oil spilled, Golob
# said.
#
# Up to 10.7 million gallons of oil was lost on Nov. 1, 1979, when
# the tanker Burmah Agate collided with another ship in Galveston
# Bay, Texas.
# However, that oil burned as well as spilled.
#
# The largest tanker spill in history resulted from the July 19,
# 1979, collision off Tobago of the supertankers Atlantic Empress and
# Aegean Captain, in which 300,000 tons _ more than 80 million
# gallons _ of oil was lost.
#
# </TEXT>
#
# </DOC>

# %%
for num, sentence in enumerate(doc_file.sents):
    print(f'{num}: {sentence}')
# Out:
# 0:
# <DOC>
# <DOCNO> AP890325-0143 </DOCNO>
# <FILEID>AP-NR-03-25-89 2357EST</FILEID>
#
# 1: <FIRST>u a AM-TankerSpill 3rdLd-Writethru a0598
# 2: 03-25 1274</FIRST>
#
# 3: <SECOND>AM-Tanker Spill, 3rd Ld-Writethru, a0598,1306</SECOND>
#
# 4: <HEAD>
# 5: Workers Try To Unload Tanker; Environmentalists Call Spill a Disaster</HEAD>
# <HEAD>Eds: INSERTS 2 grafs after 32nd, `He said...' to UPDATE with Coast
# Guard issuing subpoena to ship's master and two crewmen; picks up 33rd
# graf pvs, `Previously, the...'</HEAD>
# <HEAD>LaserPhotos AG1,2,3,4</HEAD>
#
# 6: <BYLINE>
# 7: By SUSAN GALLAGHER</BYLINE>
#
# 8: <BYLINE>Associated Press Writer</BYLINE>
#
# 9: <DATELINE>
# 10: VALDEZ, Alaska (AP) </DATELINE
# 11: >
#
# 12: <TEXT>
#
# 13: Millions of gallons of crude oil that
# spilled when a tanker ran aground spread across a wildlife-rich
# stretch of ocean Saturday, and Alaska's chief environmental officer
# criticized cleanup efforts as too slow.
#
# 14: The biggest oil spill in U.S. history created a slick about
# seven miles long and seven miles wide in Prince William Sound.
# 15: The
# group Greenpeace, in Seattle.
#
# 44: ``There's a high concentration of sea otter, waterfowl, sea
# birds and pink salmon in that area,'' said Steve Goldstein, a
# spokesman for the Interior Department in Washington.
# 45: ``Some birds
# have already died, and we are doing our best to try to save the
# fish by containing the oil to the area where it presently is and by
# trying to skim it.''
#
# 46: Whales, porpoises and seals are also common in Prince William
# Sound.
# 47: ``It's kind of like sailing through a zoo,'' said Jim
# Lethcoe, who lives on a boat in the sound and operates a sailing
# business.
#
# 48: An animal cleanup station was set up in a building at the
# community college in Valdez, but volunteers there said they had no
# animals to work on by midafternoon.
#
# 49: The response to the spill also drew fire from the 12,000-member
# United Fishermen of Alaska.
#
# 50: ``We feel that this should have been the easiest oil spill in
# the world to clean up,'' said Riki Ott, chairman of the
# organization's habitat committee.
# 51: She noted that the spill had
# occurred in a protected area close to the Valdez marine terminal
# and the water was calm.
#
# 52: Ott said the spill had polluted Prince William Sound's primary
# herring spawning area.
# 53: Fishermen also take salmon and shellfish
# from the sound.
# 54: Last year, they were paid about $85 million for
# their catches, she said.
#
# 55: The Port of Valdez remained closed to tanker traffic.
# 56: North
# Slope crude oil is shipped 800 miles through the trans-Alaska oil
# pipeline from Prudhoe Bay south to Valdez for shipment aboard
# tankers to refineries outside Alaska.
#
# 57: The Coast Guard said the Exxon Valdez struck the reef when it
# maneuvered outside normal tanker traffic lanes to avoid icebergs.
#
# 58: The vessel's captain, Joseph Hazelwood, has worked for Exxon for
# 20 years, at least 10 as a ship's master.
# 59: It was unclear if a pilot
# was aboard the Exxon Valdez when it grounded.
#
# 60: There was no decision Saturday on whether to use chemicals to
# disperse the oil, but a test of the dispersal method was being
# conducted Saturday afternoon, as was a test to determine whether at
# least some of the crude oil could be burned.
#
# 61: Coast Guard Cmdr.
# 62: Steven McCall said National Transportation
# Safety Board investigators are expected to arrive Sunday to take
# over the accident probe.
#
# 63: He said one or more blood-alcohol tests were administered after
# the grounding, but he said he didn't know know how many people were
# tested or the results.
# 64: McCall said the tests routinely are
# administered in marine accidents involving federal jurisdiction.
#
# 65: The Coast Guard issued a statement late Saturday that McCall has
# subpoenaed the ship's master and two crew members.
#
# 66: The subpoenas require them to make themselves available to NTSB
# investigators arriving Sunday.
# 67: The Coast Guard said the supoenas
# were routine.
#
# 68: Previously, the largest U.S. tanker spill was the Dec. 15, 1976,
# grounding of the Argo Merchant tanker off the Nantucket shoals off
# Massachusetts, in which 7.6 million gallons of oil spilled, Golob
# said.
#
# 69: Up to 10.7 million gallons of oil was lost on Nov. 1, 1979, when
# the tanker Burmah Agate collided with another ship in Galveston
# Bay, Texas.
# 70: However, that oil burned as well as spilled.
#
# 71: The largest tanker spill in history resulted from the July 19,
# 1979, collision off Tobago of the supertankers Atlantic Empress and
# Aegean Captain, in which 300,000 tons _ more than 80 million
# gallons _ of oil was lost.
#
# 72: </TEXT>
#
# 73: </DOC>

# %%
docx.text.split(' ')
# Out:
# ['Spacy', 'is', 'an', 'amazing', 'tool', 'and', 'you', 'know', 'it']

# %%
for word in docx:
    print(word.text,word.shape)
# Out:
# Spacy 16072095006890171862
# is 4370460163704169311
# an 4370460163704169311
# amazing 13110060611322374290
# tool 13110060611322374290
# and 4088098365541558500
# you 4088098365541558500
# know 13110060611322374290
# it 4370460163704169311

# %%
for word in docx:
    print(word.text,word.shape_)
# Out:
# Spacy Xxxxx
# is xx
# an xx
# amazing xxxx
# tool xxxx
# and xxx
# you xxx
# know xxxx
# it xx

# %%
ex_doc = nlp('Hello hello HELLO HeLLO')

# %%
for word in ex_doc:
    print("Token =>",word.text, "Shape ",word.shape_,word.is_alpha,word.is_stop)
# Out:
# Token => Hello Shape  Xxxxx True False
# Token => hello Shape  xxxx True False
# Token => HELLO Shape  XXXX True False
# Token => HeLLO Shape  XxXXX True False

# %%
ex_doc2 = nlp('Hello is hello HELLO HeLL123O bye.')

# %%
for word in ex_doc2:
    print("Token =>",word.text, "Shape ",word.shape_,word.is_alpha,word.is_stop)
# Out:
# Token => Hello Shape  Xxxxx True False
# Token => is Shape  xx True True
# Token => hello Shape  xxxx True False
# Token => HELLO Shape  XXXX True False
# Token => HeLL123O Shape  XxXXdddX False False
# Token => bye Shape  xxx True False
# Token => . Shape  . False False

# %%
# stop words are the most common words 
from spacy.lang.en.stop_words import STOP_WORDS

# %%
print(STOP_WORDS)
# Out:
# {'almost', 'less', 'just', 'go', 'thereafter', 'upon', 'eight', 'than', 'enough', 'forty', 'last', 'afterwards', 'rather', 'which', 'is', 'various', 'serious', 'that', 'few', 'becomes', 'their', 'one', 'she', 'was', 'besides', 'none', 'still', 'we', 'whole', 'once', 'also', 'some', 'doing', 'down', 'will', 'itself', 'herein', 'make', 'seeming', 'it', 'her', 'nine', 'themselves', 'former', 'via', 'our', 'two', 'ours', 'every', 'own', 'side', 'neither', 'through', 'together', 'until', 'even', 'four', 'see', 'more', 'everywhere', 'due', 'am', 'keep', 'not', 'or', 'since', 'whence', 'wherein', 'except', 'indeed', 'might', 'however', 'already', 'latter', 're', 'onto', 'put', 'something', 'say', 'off', 'those', 'empty', 'most', 'seemed', 'could', 'someone', 'about', 'and', 'meanwhile', 'then', 'very', 'anywhere', 'by', 'made', 'here', 'ten', 'therefore', 'would', 'take', 'nor', 'above', 'unless', 'whereas', 'whose', 'an', 'third', 'you', 'up', 'without', 'cannot', 'towards', 'whom', 'because', 'did', 'whereby', 'no', 'sometime', 'get', 'back', 'under', 'in', 'whatever', 'along', 'sometimes', 'moreover', 'anyone', 'us', 'me', 'yet', 'front', 'everything', 'further', 'has', 'alone', 'always', 'another', 'there', 'thereby', 'per', 'within', 'what', 'beyond', 'hence', 'seem', 'least', 'too', 'as', 'others', 'quite', 'somehow', 'the', 'must', 'amount', 'else', 'myself', 'yourself', 'move', 'behind', 'nothing', 'only', 'amongst', 'whether', 'hereupon', 'six', 'namely', 'over', 'them', 'somewhere', 'either', 'him', 'done', 'had', 'full', 'such', 'often', 'other', 'before', 'ever', 'where', 'whereafter', 'my', 'around', 'does', 'fifty', 'into', 'all', 'across', 'seems', 'out', 'now', 'i', 'noone', 'thereupon', 'top', 'among', 'wherever', 'again', 'anything', 'anyhow', 'if', 'are', 'below', 'do', 'each', 'latterly', 'hereafter', 'of', 'ourselves', 'these', 'thus', 'next', 'while', 'give', 'both', 'how', 'its', 'many', 'several', 'during', 'used', 'may', 'so', 'regarding', 'for', 'using', 'with', 'sixty', 'although', 'his', 'first', 'any', 'bottom', 'anyway', 'beforehand', 'eleven', 'he', 'much', 'hereby', 'nevertheless', 'same', 'yours', 'mine', 'please', 'nobody', 'can', 'toward', 'when', 'a', 'whither', 'elsewhere', 'hundred', 'become', 'who', 'part', 'your', 'call', 'though', 'herself', 'otherwise', 'after', 'this', 'became', 'but', 'throughout', 'should', 'nowhere', 'yourselves', 'being', 'therein', 'name', 'thru', 'everyone', 'against', 'at', 'whereupon', 'becoming', 'they', 'to', 'formerly', 'fifteen', 'have', 'from', 'really', 'twenty', 'three', 'whoever', 'why', 'been', 'never', 'perhaps', 'well', 'thence', 'himself', 'five', 'mostly', 'twelve', 'whenever', 'beside', 'show', 'were', 'be', 'between', 'on', 'hers', 'ca'}

# %%
# Checking if a word is a stopword
nlp.vocab['the'].is_stop
# Out:
# True

# %%
spacy.explain('advmod')
# Out:
# 'adverbial modifier'

# %%
ex1 = nlp("He drinks a drink")

# %%
for word in ex1:
    print(word.text,word.pos,word.pos_,word.tag,word.tag_)
# Out:
# He 94 PRON 13656873538139661788 PRP
# drinks 99 VERB 13927759927860985106 VBZ
# a 89 DET 15267657372422890137 DT
# drink 91 NOUN 15308085513773655218 NN

# %%
from spacy import displacy

# %%
import os

# %%
all_files = os.listdir("data/DUC2001/Summaries/")

# %%
all_files
# Out:
# ['ap901010-0036.txt',
#  'ft921-9310.txt',
#  'sjmn91-06290146.txt',
#  'ap900322-0192.txt',
#  'la093089-0126.txt',
#  'ap880705-0018.txt',
#  'sjmn91-06255434.txt',
#  'sjmn91-06195131.txt',
#  'wsj900918-0121.txt',
#  'ap900529-0005.txt',
#  'la102189-0151.txt',
#  'ft923-6110.txt',
#  'ap900428-0108.txt',
#  'la021689-0227.txt',
#  'sjmn91-06142126.txt',
#  'ap881211-0027.txt',
#  'la043089-0197.txt',
#  'ap890719-0225.txt',
#  'ap880913-0204.txt',
#  'ap890307-0150.txt',
#  'la061589-0143.txt',
#  'ap900215-0031.txt',
#  'sjmn91-06246065.txt',
#  'wsj871216-0037.txt',
#  'la110589-0082.txt',
#  'wsj900615-0131.txt',
#  'ft934-5781.txt',
#  'sjmn91-06184003.txt',
#  'la080790-0111.txt',
#  'la041889-0039.txt',
#  'ap891116-0115.txt',
#  'fbis3-22942.txt',
#  'sjmn91-06084228.txt',
#  'ap900928-0054.txt',
#  'ap890325-0143.txt',
#  'ft933-8941.txt',
#  'ap880601-0040.txt',
#  'ft933-6011.txt',
#  'ap880928-0146.txt',
#  'ap881017-0235.txt',
#  'la091889-0088.txt',
#  'fbis4-56863.txt',
#  'ft941-4219.txt',
#  'la110490-0184.txt',
#  'ap900910-0020.txt',
#  'ap900424-0035.txt',
#  'ap880902-0062.txt',
#  'wsj910607-0063.txt',
#  '.DS_Store',
#  'ft933-10881.txt',
#  'sjmn91-06193235.txt',
#  'ap880623-0135.txt',
#  'ap900323-0036.txt',
#  'ap890803-0008.txt',
#  'la092189-0123.txt',
#  'ft923-5797.txt',
#  'wsj880923-0163.txt',
#  'ap881222-0126.txt',
#  'ap881009-0072.txt',
#  'ap901231-0012.txt',
#  'fbis3-30788.txt',
#  'ap891028-0022.txt',
#  'la120389-0130.txt',
#  'ap900619-0006.txt',
#  'ft931-3883.txt',
#  'wsj911106-0109.txt',
#  'ft933-5709.txt',
#  'la032789-0038.txt',
#  'la081489-0025.txt',
#  'sjmn91-06136305.txt',
#  'ap890708-0135.txt',
#  'ap880926-0203.txt',
#  'ap881222-0119.txt',
#  'ap890805-0126.txt',
#  'sjmn91-06191081.txt',
#  'sjmn91-06184088.txt',
#  'fbis3-41.txt',
#  'sjmn91-06169114.txt',
#  'sjmn91-06143070.txt',
#  'ap890313-0198.txt',
#  'ft934-13350.txt',
#  'ft931-341.txt',
#  'ap901203-0166.txt',
#  'la012590-0174.txt',
#  'ap890316-0018.txt',
#  'ap890117-0132.txt',
#  'ft923-7126.txt',
#  'ft943-4951.txt',
#  'ap890907-0221.txt',
#  'ap891213-0004.txt',
#  'ft923-6038.txt',
#  'wsj900914-0127.txt',
#  'sjmn91-06105230.txt',
#  'wsj911212-0080.txt',
#  'ap880811-0299.txt',
#  'wsj910405-0154.txt',
#  'ap890704-0043.txt',
#  'la070189-0080.txt',
#  'ft934-8748.txt',
#  'fbis-45908.txt',
#  'ap890501-0176.txt',
#  'sjmn91-06161012.txt',
#  'ap901030-0216.txt',
#  'la110590-0038.txt',
#  'wsj910709-0115.txt',
#  'ft934-8628.txt',
#  'ap880714-0142.txt',
#  'sjmn91-06312120.txt',
#  'wsj911030-0008.txt',
#  'ap880705-0109.txt',
#  'ft923-5859.txt',
#  'la010890-0031.txt',
#  'ap880901-0052.txt',
#  'ap880409-0015.txt',
#  'ft933-2760.txt',
#  'ap900511-0159.txt',
#  'ap900601-0040.txt',
#  'ap890930-0100.txt',
#  'wsj910326-0090.txt',
#  'sjmn91-06301029.txt',
#  'ap890302-0063.txt',
#  'ap890111-0227.txt',
#  'la040789-0051.txt',
#  'la103089-0043.txt',
#  'wsj910710-0123.txt',
#  'ap891210-0079.txt',
#  'la042190-0060.txt',
#  'la030789-0047.txt',
#  'sjmn91-06129119.txt',
#  'wsj900418-0193.txt',
#  'la121189-0017.txt',
#  'ap880913-0129.txt',
#  'sjmn91-06193081.txt',
#  'ft933-8272.txt',
#  'ap880927-0117.txt',
#  'ap880613-0161.txt',
#  'ap890404-0260.txt',
#  'ap901029-0035.txt',
#  'wsj900720-0113.txt',
#  'wsj880621-0079.txt',
#  'ap900703-0040.txt',
#  'wsj910107-0139.txt',
#  'la072089-0140.txt',
#  'ap880927-0089.txt',
#  'la051190-0185.txt',
#  'la101690-0040.txt',
#  'la071590-0068.txt',
#  'ap881018-0136.txt',
#  'ap881126-0007.txt',
#  'ft932-12322.txt',
#  'fbis3-23360.txt',
#  'ap880419-0131.txt',
#  'la030889-0163.txt',
#  'ap880816-0234.txt',
#  'wsj880617-0024.txt',
#  'ap890802-0064.txt',
#  'wsj911031-0012.txt',
#  'wsj870908-0047.txt',
#  'la103089-0070.txt',
#  'ap890131-0280.txt',
#  'ft923-5089.txt',
#  'ap901012-0032.txt',
#  'ap900416-0188.txt',
#  'ft922-10200.txt',
#  'wsj890828-0011.txt',
#  'fbis3-11919.txt',
#  'ap880520-0264.txt',
#  'ap900629-0260.txt',
#  'wsj910208-0130.txt',
#  'ap881216-0017.txt',
#  'sjmn91-06276078.txt',
#  'la051590-0065.txt',
#  'sjmn91-06071022.txt',
#  'ft934-11014.txt',
#  'ap881206-0114.txt',
#  'wsj910718-0143.txt',
#  'ap890111-0217.txt',
#  'ft942-11114.txt',
#  'ap890529-0030.txt',
#  'ap890322-0010.txt',
#  'ap880629-0159.txt',
#  'ft911-3463.txt',
#  'ap891006-0029.txt',
#  'ft923-5267.txt',
#  'la092790-0010.txt',
#  'wsj900705-0145.txt',
#  'ap900428-0005.txt',
#  'fbis-41815.txt',
#  'wsj870306-0171.txt',
#  'ap900607-0039.txt',
#  'la081890-0039.txt',
#  'fbis4-27602.txt',
#  'sjmn91-06012224.txt',
#  'ft911-5176.txt',
#  'ap901031-0024.txt',
#  'ap880801-0195.txt',
#  'la073089-0118.txt',
#  'ap890801-0025.txt',
#  'ap900625-0160.txt',
#  'ft934-9116.txt',
#  'ap880914-0027.txt',
#  'ap881227-0185.txt',
#  'ap901130-0060.txt',
#  'fbis3-51875.txt',
#  'ft922-3171.txt',
#  'wsj870227-0149.txt',
#  'la102190-0045.txt',
#  'wsj910702-0078.txt',
#  'ap900721-0110.txt',
#  'ap890722-0081.txt',
#  'la030489-0068.txt',
#  'ap881210-0115.txt',
#  'la060490-0083.txt',
#  'ap880331-0140.txt',
#  'la101289-0194.txt',
#  'ft931-11394.txt',
#  'ap900829-0120.txt',
#  'la042290-0104.txt',
#  'la052289-0050.txt',
#  'ap880517-0226.txt',
#  'la011889-0067.txt',
#  'wsj910628-0109.txt',
#  'ap890511-0126.txt',
#  'ft941-575.txt',
#  'wsj870818-0002.txt',
#  'ft923-6455.txt',
#  'ft923-5835.txt',
#  'ap880903-0092.txt',
#  'ap890714-0129.txt',
#  'sjmn91-06184021.txt',
#  'la120290-0163.txt',
#  'sjmn91-06191174.txt',
#  'ap900306-0105.txt',
#  'la080189-0042.txt',
#  'ft922-8860.txt',
#  'ap891017-0204.txt',
#  'wsj911224-0085.txt',
#  'ap890227-0016.txt',
#  'la042790-0205.txt',
#  'ap900426-0054.txt',
#  'ap900419-0121.txt',
#  'la100789-0007.txt',
#  'wsj920211-0036.txt',
#  'wsj911121-0136.txt',
#  'ft943-5628.txt',
#  'la012090-0090.txt',
#  'ap890325-0029.txt',
#  'ap890314-0237.txt',
#  'ap900512-0038.txt',
#  'ft932-5855.txt',
#  'wsj910304-0005.txt',
#  'ap880705-0006.txt',
#  'ap900521-0063.txt',
#  'ap891201-0100.txt',
#  'la081490-0030.txt',
#  'ap880330-0119.txt',
#  'ap880630-0295.txt',
#  'wsj910529-0003.txt',
#  'la101090-0017.txt',
#  'sjmn91-06189077.txt',
#  'ap881222-0089.txt',
#  'ap880510-0178.txt',
#  'wsj920114-0145.txt',
#  'wsj920103-0037.txt',
#  'la042490-0142.txt',
#  'ap901013-0046.txt',
#  'ap900313-0191.txt',
#  'wsj870123-0101.txt',
#  'ap890502-0205.txt',
#  'ap890403-0123.txt',
#  'sjmn91-06182091.txt',
#  'ap890922-0167.txt',
#  'ap900217-0078.txt',
#  'ap880914-0079.txt',
#  'wsj910710-0148.txt',
#  'fbis4-67721.txt',
#  'ft941-1750.txt',
#  'ap900316-0028.txt',
#  'sjmn91-06187248.txt',
#  'sjmn91-06192123.txt',
#  'ap900322-0200.txt',
#  'la040689-0056.txt',
#  'ft921-305.txt',
#  'wsj871215-0109.txt',
#  'wsj870501-0141.txt',
#  'la050889-0075.txt',
#  'ft941-1547.txt',
#  'sjmn91-06283083.txt',
#  'la081589-0043.txt',
#  'ap890228-0019.txt',
#  'la032589-0044.txt',
#  'ft944-18184.txt',
#  'ft934-12800.txt',
#  'ap890326-0081.txt',
#  'sjmn91-06212161.txt',
#  'la092490-0095.txt',
#  'la093089-0076.txt',
#  'ft922-6646.txt',
#  'ft911-2650.txt',
#  'ap880318-0051.txt',
#  'wsj910304-0002.txt',
#  'la021090-0005.txt',
#  'ft943-12341.txt']

# %%
import glob

# %%
all_files = glob.glob("data/DUC2001/Summaries/*.txt")

# %%
all_files
# Out:
# ['data/DUC2001/Summaries/ap901010-0036.txt',
#  'data/DUC2001/Summaries/ft921-9310.txt',
#  'data/DUC2001/Summaries/sjmn91-06290146.txt',
#  'data/DUC2001/Summaries/ap900322-0192.txt',
#  'data/DUC2001/Summaries/la093089-0126.txt',
#  'data/DUC2001/Summaries/ap880705-0018.txt',
#  'data/DUC2001/Summaries/sjmn91-06255434.txt',
#  'data/DUC2001/Summaries/sjmn91-06195131.txt',
#  'data/DUC2001/Summaries/wsj900918-0121.txt',
#  'data/DUC2001/Summaries/ap900529-0005.txt',
#  'data/DUC2001/Summaries/la102189-0151.txt',
#  'data/DUC2001/Summaries/ft923-6110.txt',
#  'data/DUC2001/Summaries/ap900428-0108.txt',
#  'data/DUC2001/Summaries/la021689-0227.txt',
#  'data/DUC2001/Summaries/sjmn91-06142126.txt',
#  'data/DUC2001/Summaries/ap881211-0027.txt',
#  'data/DUC2001/Summaries/la043089-0197.txt',
#  'data/DUC2001/Summaries/ap890719-0225.txt',
#  'data/DUC2001/Summaries/ap880913-0204.txt',
#  'data/DUC2001/Summaries/ap890307-0150.txt',
#  'data/DUC2001/Summaries/la061589-0143.txt',
#  'data/DUC2001/Summaries/ap890326-0081.txt',
#  'data/DUC2001/Summaries/sjmn91-06212161.txt',
#  'data/DUC2001/Summaries/la092490-0095.txt',
#  'data/DUC2001/Summaries/la093089-0076.txt',
#  'data/DUC2001/Summaries/ft922-6646.txt',
#  'data/DUC2001/Summaries/ft911-2650.txt',
#  'data/DUC2001/Summaries/ap880318-0051.txt',
#  'data/DUC2001/Summaries/wsj910304-0002.txt',
#  'data/DUC2001/Summaries/la021090-0005.txt',
#  'data/DUC2001/Summaries/ft943-12341.txt']

# %%
len(all_files)
# Out:
# 302

# %%
# for _ in all_files:
word_dict={}
with open(all_files[0],'rt') as dd:
    file1 = nlp(dd.read())
    for word in file1:
        print(word.text,word.tag_)
#         if word.text not in word_dict:
#             word_dict.update({word.text:1})
#         else:
#             word_dict[word.text] += 1
# Out:
# Abstract NNP
# : :
#
#
# A NNP
# United NNP
# States NNP
# Air NNP
# Force NNP
# F-111 NNP
# fighter NN
# - HYPH
# bomber NN
# crashed VBD
# at IN
# dawn NN
# today NN
# in IN
# Saudi NNP
# Arabia NNP
# . .
# Both DT
# crew NN
# members NNS
# were VBD
# killed VBN
# . .
# The DT
# aircraft NN
# was VBD
# assigned VBN
# to IN
# the DT
# 48th JJ
# Tactical NNP
# Fighter NNP
# Wing NNP
# at IN
# Lakenheath NNP
# in IN
# Britain NNP
# , ,
# and CC
# was VBD
# deployed VBN
# to IN
# Saudi NNP
# Arabia NNP
# via IN
# Turkey NNP
# as IN
# Operation NNP
# Desert NNP
# Shield NNP
# progressed VBD
# . .
# The DT
# F-111 NNP
# crash NN
# followed VBD
# closely RB
# upon IN
# Monday NNP
# 's POS
# disappearance NN
# of IN
# two CD
# Marine NNP
# Corps NNP
# UH-1 NNP
# Huey NNP
# helicopters NNS
# over IN
# the DT
# Arabian NNP
# Sea NNP
# , ,
# and CC
# the DT
# crash NN
# of IN
# an DT
# Air NNP
# Force NNP
# F-4 NNP
# reconnaissance NN
# jet NN
# on IN
# the DT
# same JJ
# day NN
# . .
# Today NN
# 's POS
# crash NN
# raises VBZ
# the DT
# number NN
# of IN
# Americans NNPS
# killed VBN
# in IN
# Saudi NNP
# Arabia NNP
# to IN
# at RB
# least RBS
# nine CD
# . .
#
#
# Introduction NN
# : :
#
#     _SP
# A DT
# U.S. NNP
# Air NNP
# Force NNP
# F-111 NNP
#
#
# fighter NN
# - HYPH
# bomber NN
# crashed VBD
# today NN
# in IN
# Saudi NNP
# Arabia NNP
# , ,
# killing VBG
# both DT
# crew NN
#
#
# members NNS
# , ,
# U.S. NNP
# military JJ
# officials NNS
# reported VBD
# . .
#
#     _SP
# It PRP
# was VBD
# the DT
# fourth JJ
# American JJ
# aircraft NN
# to TO
# crash VB
# in IN
# three CD
# days NNS
# among IN
#
#
# those DT
# deployed VBN
# to IN
# this DT
# kingdom NN
# for IN
# Operation NNP
# Desert NNP
# Shield NNP
# . .
#
#     _SP
# Eight NNP
# Marines NNPS
# are VBP
# missing VBG
# in IN
# the DT
# crash NN
# of IN
# two CD
# helicopters NNS
# in IN
# the DT
#
#
# northern JJ
# Arabian NNP
# Sea NNP
# on IN
# Monday NNP
# . .
# An DT
# Air NNP
# Force NNP
# F-4 NNP
# reconnaissance NN
# jet NN
#
#
# also RB
# went VBD
# down RP
# that DT
# day NN
# , ,
# killing VBG
# both DT
# crew NN
# members NNS
# . .
#
#     _SP
# Lt NNP
# . .
# Cmdr NNP
# . .
# J.D. NNP
# van NNP
# Sickle NNP
# , ,
# a DT
# military JJ
# spokesman NN
# , ,
# said VBD
# the DT
# F-111 NNP
#
#
# crashed VBD
# in IN
# the DT
# `` ``
# southern JJ
# Arabian JJ
# peninsula NN
# '' ''
# while IN
# on IN
# a DT
# training NN
#
#
# mission NN
# and CC
# that IN
# the DT
# incident NN
# was VBD
# under IN
# investigation NN
# . .
#
#     _SP
# The DT
# names NNS
# of IN
# the DT
# flyers NNS
# were VBD
# withheld VBN
# pending VBG
# notification NN
# of IN
#
#
# next JJ
# of IN
# kin NN
# . .
#
#     _SP
# The DT
# aircraft NN
# was VBD
# attached VBN
# the DT
# 48th JJ
# Tactical NNP
# Fighter NNP
# Wing NNP
# based VBN
#
#
# at IN
# RAF NNP
# Lakenheath NNP
# Air NNP
# Base NNP
# in IN
# Britain NNP
# . .
# The DT
# wing NN
# was VBD
# sent VBN
# to IN
# Turkey NNP
#
#
# as IN
# U.S. NNP
# forces NNS
# massed VBD
# in IN
# the DT
# region NN
# in IN
# response NN
# to IN
# Iraq NNP
# 's POS
# Aug. NNP
# 2 CD
#
#
# takeover NN
# of IN
# Kuwait NNP
# . .
#
#     _SP
# Today NNP
# 's POS
# crash NN
# brought VBD
# to IN
# at RB
# least RBS
# nine CD
# the DT
# number NN
# of IN
# Americans NNPS
#
#
# killed VBN
# in IN
# the DT
# Persian NNP
# Gulf NNP
# region NN
# since IN
# Operation NNP
# Desert NNP
# Shield NNP
#
#
# began VBD
# . .
#
#     _SP
# The DT
# eight CD
# Marines NNPS
# aboard IN
# the DT
# two CD
# UH-1 NNP
# Huey NNP
# helicopters NNS
# that WDT
#
#
# vanished VBD
# Monday NNP
# are VBP
# still RB
# officially RB
# listed VBN
# as IN
# missing VBG
# . .
#
#     _SP
# In IN
# addition NN
# to IN
# those DT
# killed VBN
# in IN
# Saudi NNP
# Arabia NNP
# , ,
# 13 CD
# other JJ
# Air NNP
# Force NNP
#
#
# personnel NNS
# were VBD
# killed VBN
# in IN
# a DT
# crash NN
# of IN
# a DT
# C-5 NNP
# jet NN
# cargo NN
# plane NN
# in IN
#
#
# Germany NNP
# . .
# That DT
# aircraft NN
# was VBD
# ferrying VBG
# supplies NNS
# and CC
# equipment NN
# to IN
# the DT
#
#
# Saudi JJ
# peninsula NN
# . .
#
#     _SP
# Officials NNP
# said VBD
# the DT
# F-111 NNP
# crashed VBD
# at IN
# dawn NN
# . .
#
#     _SP
# The DT
# aircraft NN
# was VBD
# an DT
# F NNP
# - HYPH
# model NN
# , ,
# the DT
# latest JJS
# version NN
# of IN
# the DT
#
#
# 23-year CD
# - HYPH
# old JJ
# swing NN
# - HYPH
# wing NN
# jet NN
# that WDT
# first RB
# saw VBD
# action NN
# in IN
# Vietnam NNP
# . .
#
#     _SP
# The DT
# F NNP
# - HYPH
# model NN
# has VBZ
# more RBR
# powerful JJ
# engines NNS
# , ,
# and CC
# state NN
# - HYPH
# of IN
# - HYPH
# the DT
# - HYPH
# art NN
#
#
# equipment NN
# to TO
# operate VB
# against IN
# enemy NN
# targets NNS
# at IN
# night NN
# . .
# The DT
# plane NN
# can MD
#
#
# carry VB
# up RP
# to TO
# 12 CD
# tons NNS
# of IN
# bombs NNS
# and CC
# missiles NNS
# and CC
# has VBZ
# a DT
# crew NN
# of IN
# two CD
# , ,
# a DT
#
#
# pilot NN
# and CC
# a DT
# weapons NNS
# systems NNS
# officer NN
# . .
#
#
#  VBP

# %%
# Out:
# {'Abstract': 1,
#  ':': 2,
#  '\n': 24,
#  'A': 2,
#  'United': 1,
#  'States': 1,
#  'Air': 6,
#  'Force': 5,
#  'F-111': 5,
#  'fighter': 2,
#  '-': 9,
#  'bomber': 2,
#  'crashed': 4,
#  'at': 7,
#  'dawn': 2,
#  'today': 2,
#  'in': 16,
#  'Saudi': 6,
#  'Arabia': 5,
#  '.': 23,
#  'Both': 1,
#  'crew': 4,
#  'members': 3,
#  'were': 3,
#  'killed': 5,
#  'The': 9,
#  'aircraft': 5,
#  'was': 8,
#  'assigned': 1,
#  'to': 12,
#  'the': 22,
#  '48th': 2,
#  'Tactical': 2,
#  'Fighter': 2,
#  'Wing': 2,
#  'Lakenheath': 2,
#  'Britain': 2,
#  ',': 11,
#  'and': 8,
#  'deployed': 2,
#  'via': 1,
#  'Turkey': 2,
#  'as': 3,
#  'Operation': 3,
#  'Desert': 3,
#  'Shield': 3,
#  'progressed': 1,
#  'crash': 7,
#  'followed': 1,
#  'closely': 1,
#  'upon': 1,
#  'Monday': 3,
#  "'s": 4,
#  'disappearance': 1,
#  'of': 14,
#  'two': 4,
#  'Marine': 1,
#  'Corps': 1,
#  'UH-1': 2,
#  'Huey': 2,
#  'helicopters': 3,
#  'over': 1,
#  'Arabian': 3,
#  'Sea': 2,
#  'an': 2,
#  'F-4': 2,
#  'reconnaissance': 2,
#  'jet': 4,
#  'on': 3,
#  'same': 1,
#  'day': 2,
#  'Today': 2,
#  'raises': 1,
#  'number': 2,
#  'Americans': 2,
#  'least': 2,
#  'nine': 2,
#  'Introduction': 1,
#  '\n   ': 12,
#  'U.S.': 3,
#  'killing': 2,
#  'both': 2,
#  'military': 2,
#  'officials': 1,
#  'reported': 1,
#  'It': 1,
#  'fourth': 1,
#  'American': 1,
#  'three': 1,
#  'days': 1,
#  'among': 1,
#  'those': 2,
#  'this': 1,
#  'kingdom': 1,
#  'for': 1,
#  'Eight': 1,
#  'Marines': 2,
#  'are': 2,
#  'missing': 2,
#  'northern': 1,
#  'An': 1,
#  'also': 1,
#  'went': 1,
#  'down': 1,
#  'that': 4,
#  'Lt': 1,
#  'Cmdr': 1,
#  'J.D.': 1,
#  'van': 1,
#  'Sickle': 1,
#  'a': 7,
#  'spokesman': 1,
#  'said': 2,
#  '``': 1,
#  'southern': 1,
#  'peninsula': 2,
#  "''": 1,
#  'while': 1,
#  'training': 1,
#  'mission': 1,
#  'incident': 1,
#  'under': 1,
#  'investigation': 1,
#  'names': 1,
#  'flyers': 1,
#  'withheld': 1,
#  'pending': 1,
#  'notification': 1,
#  'next': 1,
#  'kin': 1,
#  'attached': 1,
#  'based': 1,
#  'RAF': 1,
#  'Base': 1,
#  'wing': 2,
#  'sent': 1,
#  'forces': 1,
#  'massed': 1,
#  'region': 2,
#  'response': 1,
#  'Iraq': 1,
#  'Aug.': 1,
#  '2': 1,
#  'takeover': 1,
#  'Kuwait': 1,
#  'brought': 1,
#  'Persian': 1,
#  'Gulf': 1,
#  'since': 1,
#  'began': 1,
#  'eight': 1,
#  'aboard': 1,
#  'vanished': 1,
#  'still': 1,
#  'officially': 1,
#  'listed': 1,
#  'In': 1,
#  'addition': 1,
#  '13': 1,
#  'other': 1,
#  'personnel': 1,
#  'C-5': 1,
#  'cargo': 1,
#  'plane': 2,
#  'Germany': 1,
#  'That': 1,
#  'ferrying': 1,
#  'supplies': 1,
#  'equipment': 2,
#  'Officials': 1,
#  'F': 2,
#  'model': 2,
#  'latest': 1,
#  'version': 1,
#  '23-year': 1,
#  'old': 1,
#  'swing': 1,
#  'first': 1,
#  'saw': 1,
#  'action': 1,
#  'Vietnam': 1,
#  'has': 2,
#  'more': 1,
#  'powerful': 1,
#  'engines': 1,
#  'state': 1,
#  'art': 1,
#  'operate': 1,
#  'against': 1,
#  'enemy': 1,
#  'targets': 1,
#  'night': 1,
#  'can': 1,
#  'carry': 1,
#  'up': 1,
#  '12': 1,
#  'tons': 1,
#  'bombs': 1,
#  'missiles': 1,
#  'pilot': 1,
#  'weapons': 1,
#  'systems': 1,
#  'officer': 1,
#  '\x1a': 1}

# %%
import glob
import gensim

all_files = glob.glob('data/DUC2001/Summaries/*.txt')

string = ''

for _ in range(len(all_files)):
    with open(all_files[_],'rt') as file:
        txt_file = file.read()
        for word in txt_file:
            string += word
        with open('data1/sample{}.txt'.format(_),'w') as file1:
            file1.write('{}'.format(string))

# %%
string
# Out:
# 'Abstract:\nA United States Air Force F-111 fighter-bomber crashed at dawn today in Saudi Arabia. Both crew members were killed. The aircraft was assigned to the 48th Tactical Fighter Wing at Lakenheath in Britain, and was deployed to Saudi Arabia via Turkey as Operation Desert Shield progressed. The F-111 crash followed closely upon Monday\'s disappearance of two Marine Corps UH-1 Huey helicopters over the Arabian Sea, and the crash of an Air Force F-4 reconnaissance jet on the same day. Today\'s crash raises the number of Americans killed in Saudi Arabia to at least nine.\nIntroduction:\n   A U.S. Air Force F-111\nfighter-bomber crashed today in Saudi Arabia, killing both crew\nmembers, U.S. military officials reported.\n   It was the fourth American aircraft to crash in three days among\nthose deployed to this kingdom for Operation Desert Shield.\n   Eight Marines are missing in the crash of two helicopters in the\nnorthern Arabian Sea on Monday. An Air Force F-4 reconnaissance jet\nalso went down that day, killing both crew members.\n   Lt. Cmdr. J.D. van Sickle, a military spokesman, said the F-111\ncrashed in the ``southern Arabian peninsula\'\' while on a training\nmission and that the incident was under investigation.\n   The names of the flyers were withheld pending notification of\nnext of kin.\n   The aircraft was attached the 48th Tactical Fighter Wing based\nat RAF Lakenheath Air Base in Britain. The wing was sent to Turkey\nas U.S. forces massed in the region in response to Iraq\'s Aug. 2\ntakeover of Kuwait.\n   Today\'s crash brought to at least nine the number of Americans\nkilled in the Persian Gulf region since Operation Desert Shield\nbegan.\n   The eight Marines aboard the two UH-1 Huey helicopters that\nvanished Monday are still officially listed as missing.\n   In addition to those killed in Saudi Arabia, 13 other Air Force\npersonnel were killed in a crash of a C-5 jet cargo plane in\nGermany. That aircraft was ferrying supplies and equipment to the\nSaudi peninsula.\n   Officials said the F-111 crashed at dawn.\n   The aircraft was an F-model, the latest version of the\n23-year-old swing-wing jet that first saw action in Vietnam.\n   The F-model has more powerful engines, and state-of-the-art\nequipment to operate against enemy targets at night. The plane can\ncarry up to 12 tons of bombs and missiles and has a crew of two, a\npilot and a weapons systems officer.\n\x1aAbstract:\n"Mad cow disease" (bovine spongiform encephalopathy or BSE), has been found in Britain\'s sparsely scattered antelope population, including elands, kuru and an Arabian oryx. In all, six species other than cattle have been confirmed with the disease over the past three years. There has also been a pronounced increase in the number of sheep affected by the ovine form of the disease ("scrapie") with 894 cases diagnosed in 1991 compared to just 348 in 1990. Since 1989 the condition has been confirmed in 23 cats and 29 goats. There is not sufficient data to conclude how the disease is spread.\nIntroduction:\nTHE CONDITION known in cattle as \'mad cow disease\', spongiform\nencephalopathies, has been found in Britain\'s sparsely-scattered antelope\npopulation, the government has admitted.\nThree elands, three greater kudu and an arabian oryx have been diagnosed\nwith the disease over the past three years. In all, six species other than\ncattle have been confirmed with the condition during this period.\nThe statistics - released in response to a written question from Mr Ron\nDavies, a Labour agriculture spokesman - show a disconcertingly rapid\nincrease in the number of sheep found to have the disease.\nA total of 894 cases of sheep encephalopathies or \'scrapie\' were diagnosed\nin 1991, versus just 348 a year-earlier. However, the government states in a\nfootnote to the table that the reporting of scrapie in sheep has been\nencouraged since 1991 \'to obtain material for spongiform encephalopathy\nresearch\'.\nSince 1989, the conditi ...

# %%
all_files1 = glob.glob('data1/*.txt')

def read_input(input_file):
    with open(input_file,'rt') as f:
        for line in f:
            yield gensim.utils.simple_preprocess(line)

documents1 = []
documents2 = []
documents3 = []

for _ in range(len(all_files1)):
    documents = list(read_input('{}'.format(all_files1[_])))
    for __ in range(len(documents)):
        for ___ in range(len(documents[__])):
            documents1.append(documents[__][___])

    for __ in range(len(documents1)):
        if documents1[__] == 'introduction':
            documents2.append(documents1[__+1:])

    documents3.append(documents2)

with open('list_word.txt','w') as file2:
    file2.write('{}'.format(documents3))
